# %%
import time
import numpy as np
import mediapipe as mp
import torch
from torchvision.transforms import functional as F
import cv2
from ultralytics import YOLO
from src.utils import intersection_over_union
from src.elements import face_detect, head_Pose
import pyttsx3
import threading
engine = pyttsx3.init()

def speak(text):
    engine.say(text)
    engine.runAndWait()

# Check if CUDA is available and set the device accordingly
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

# load Detection model & facemesh
coco128 = open('./coco128.txt', 'r')
data = coco128.read()
class_list = data.split('\n')
coco128.close()

model = YOLO('./yolov8s.pt')
model.to(device)

mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# camera setting 
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

# hyperparameter setting
CONFIDENCE_THRESHOLD = 0.8    # 최소 정확도 이하의 객체는 화면에 출력하지 않음
iou_threshold = 0.8           # 유사도 IoU 기준
stable_threshold_time = 1.5   # 움직임 안정 여부 시간(s) 기준
pct_threshold = 10            # 얼굴 비중 안내 기준

# constants
GREEN = (0, 255, 0)       
WHITE = (255, 255, 255)   
BLUE = (0, 0, 255)

last_change_time = time.time()
last_bbox = None
max_area = 0
max_box = None

original_dim = (1280, 720)
resize_dim = (640, 640)
# Scale factors for coordinates
x_scale = original_dim[0] / resize_dim[0]
y_scale = original_dim[1] / resize_dim[1]

# 말을 한번만 하기 위해서 상태를 나타내는 변수 도입 -> 1일 때만 말해줄거야
state_loc_variable = 1

# DETECTION
while True:
    start = time.time()
    success, frame = cap.read()
    if not success:
        print('Cam Error')
        break

    # 요소 3 : head pose estimation
    #headpose = head_Pose(image=frame, face_mesh=face_mesh)
    # 좌우반전
    frame = cv2.flip(frame, 1)
    ##### TODO : 요소3 안내 조건 조정 및 추가 #####
    #cv2.putText(frame, headpose, (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.5, GREEN, 2)
    
    # resize and move the frame to the same device as the model
    frame_resized = cv2.resize(frame, (640, 640))
    frame_tensor = F.to_tensor(frame_resized).unsqueeze(0).to(device)

    detection = model.predict(frame,conf=CONFIDENCE_THRESHOLD)[0]
    for data in detection.boxes.data.tolist(): 
        # data : [xmin, ymin, xmax, ymax, confidence_score, class_id]
        xmin, ymin, xmax, ymax, conf, label = int(data[0]), int(data[1]), int(data[2]), int(data[3]), float(data[4]), int(data[5])
        xmin = int(xmin * x_scale)
        ymin = int(ymin * y_scale)
        xmax = int(xmax * x_scale)
        ymax = int(ymax * y_scale)

        if label!=0:
             continue
        
        # 가장 큰 사이즈의 박스만 pass
        area = (xmax-xmin)*(ymax-ymin)
        if area > max_area:
             max_area = area
             max_box = [xmin, ymin, xmax, ymax, conf, label]
    
    if max_box:
        # bbox 표시
        new_bbox = max_box[:3]
        cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), GREEN, 2)
        cv2.putText(frame, class_list[label]+' '+str(round(conf, 2)), (xmin, ymin-10), cv2.FONT_ITALIC, 1, WHITE, 2)

        if last_bbox is not None:
            iou = intersection_over_union(last_bbox, new_bbox)
            if iou < iou_threshold:
                 last_change_time = time.time()
                 state_loc_variable = 1

            elif (time.time() - last_change_time) > stable_threshold_time and state_loc_variable == 1:

                # 요소 1 & 2 탐지 시작
                pct, loc = face_detect(xmin,ymin,xmax,ymax,frame)
                # (요소1)
                if pct > pct_threshold: # TODO: 요소1 조건 조정
                    pct_text = f"object percentage: {pct}%"
                    cv2.putText(frame, pct_text, (20, 100), cv2.FONT_HERSHEY_SIMPLEX, 0.5, GREEN, 2)
                # (요소2)
                loc_text = f"object location : {loc}"
                cv2.putText(frame, loc_text, (20, 150), cv2.FONT_HERSHEY_SIMPLEX, 0.5, GREEN, 2)
                # (TTS)
                threading.Thread(target=speak, args=(f"현재 얼굴 비중은 {pct}%이고 얼굴 위치는 {loc}이다.",)).start()

                # 안내 완료 후 타이머 리셋
                last_change_time = time.time()
                # state_loc_variable 리셋
                state_loc_variable = 0 
        
        last_bbox = new_bbox

    max_area = 0
    max_box = None

    # fps 계산
    end = time.time()
    totalTime = (end - start)
    fps = f'FPS: {1 / totalTime:.2f}'
    print(f'Time to process 1 frame: {totalTime * 1000:.0f} milliseconds')
    print(fps)
        
    cv2.putText(frame, fps, (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, BLUE, 2) # fps 표시
    cv2.imshow('frame', frame)
        
    if cv2.waitKey(1) == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Using device: cpu
#
# 0: 384x640 1 person, 268.8ms
# Speed: 4.2ms preprocess, 268.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 769 milliseconds
# FPS: 1.30
#
# 0: 384x640 1 person, 269.3ms
# Speed: 2.0ms preprocess, 269.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 108
#     105 cv2.putText(frame, class_list[label]+' '+str(round(conf, 2)), (xmin, ymin-10), cv2.FONT_ITALIC, 1, WHITE, 2)
#     107 if last_bbox is not None:
# --> 108     iou = intersection_over_union(last_bbox, new_bbox)
#     109     if iou < iou_threshold:
#     110          last_change_time = time.time()
#
# File c:\Users\happy\Desktop\camera_ObjectDetection\전면카메라\YOLOv8\src\utils.py:7, in intersection_over_union(boxA, boxB)
#       5 y_min = max(boxA[1],boxB[1])
#       6 x_max = min(boxA[2],boxB[2])
# ----> 7 y_max = min(boxA[3],boxB[3])
#       9 # Intersection 영역
#      10 intersection_area = max(x_max-x_min,0) * max(y_max-y_min,0)
#
# IndexError: list index out of range

# %%
model = YOLO('./best.pt')
model
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): Upsample(scale_factor=2.0, mode='nearest')
#       (11): Concat()
#       (12): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (13): Upsample(scale_factor=2.0, mode='nearest')
#       (14): Concat()
#       (15): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (16): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (17): Concat()
#       (18): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (19): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (20): Concat()
#       (21): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (22): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )

# %%
import requests
from PIL import Image
from ultralytics import YOLO
import cv2
import numpy as np

# load model
model = YOLO('./best.pt')

# perform inference
results = model('./selfie.jpg')

# Convert the PIL segmentation mask to numpy array
segmentation_array = results[0].plot()

# Display the segmentation mask using OpenCV
cv2.imshow('YOLO Segmentation', segmentation_array)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 c:\Users\happy\Desktop\camera_ObjectDetection\\YOLOv8\selfie.jpg: 448x640 2 FACEs, 342.3ms
# Speed: 3.6ms preprocess, 342.3ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)

# %%
detection.boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0.])
# conf: tensor([0.8811, 0.8806])
# data: tensor([[516.8550, 138.4368, 655.0471, 337.2710,   0.8811,   0.0000],
#         [407.4715, 108.2561, 510.6542, 241.8674,   0.8806,   0.0000]])
# id: None
# is_track: False
# orig_shape: (667, 1000)
# shape: torch.Size([2, 6])
# xywh: tensor([[585.9510, 237.8539, 138.1921, 198.8342],
#         [459.0628, 175.0618, 103.1827, 133.6113]])
# xywhn: tensor([[0.5860, 0.3566, 0.1382, 0.2981],
#         [0.4591, 0.2625, 0.1032, 0.2003]])
# xyxy: tensor([[516.8550, 138.4368, 655.0471, 337.2710],
#         [407.4715, 108.2561, 510.6542, 241.8674]])
# xyxyn: tensor([[0.5169, 0.2076, 0.6550, 0.5057],
#         [0.4075, 0.1623, 0.5107, 0.3626]])

# %%
detection = model.predict('./selfie.jpg', conf = 0.5)[0]
for data in detection.boxes.data.tolist(): 
    # data : [xmin, ymin, xmax, ymax, confidence_score, class_id]
    xmin, ymin, xmax, ymax, conf, label = int(data[0]), int(data[1]), int(data[2]), int(data[3]), float(data[4]), int(data[5])
    print(label)
# Out:
# image 1/1 c:\Users\happy\Desktop\camera_ObjectDetection\\YOLOv8\selfie.jpg: 448x640 2 FACEs, 378.4ms
# Speed: 3.0ms preprocess, 378.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 0
# 0

# %%
detection = model.predict(frame,conf=CONFIDENCE_THRESHOLD)[0]
    for data in detection.boxes.data.tolist(): 
        # data : [xmin, ymin, xmax, ymax, confidence_score, class_id]
        xmin, ymin, xmax, ymax, conf, label = int(data[0]), int(data[1]), int(data[2]), int(data[3]), float(data[4]), int(data[5])
        xmin = int(xmin * x_scale)
        ymin = int(ymin * y_scale)
        xmax = int(xmax * x_scale)
        ymax = int(ymax * y_scale)

        if label!=0:
             continue
        
        # 가장 큰 사이즈의 박스만 pass
        area = (xmax-xmin)*(ymax-ymin)
        if area > max_area:
             max_area = area
             max_box = [xmin, ymin, xmax, ymax, conf, label]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'FACE'}
# obb: None
# orig_img: array([[[251, 246, 243],
#         [251, 246, 243],
#         [251, 246, 243],
#         ...,
#         [252, 254, 254],
#         [252, 254, 254],
#         [252, 254, 254]],
#
#        [[251, 246, 243],
#         [251, 246, 243],
#         [251, 246, 243],
#         ...,
#         [252, 254, 254],
#         [252, 254, 254],
#         [252, 254, 254]],
#
#        [[251, 246, 243],
#         [251, 246, 243],
#         [251, 246, 243],
#         ...,
#         [252, 254, 254],
#         [252, 254, 254],
#         [252, 254, 254]],
#
#        ...,
#
#        [[130, 130, 130],
#         [130, 128, 134],
#         [127, 129, 130],
#         ...,
#         [ 91, 120, 187],
#         [ 91, 123, 189],
#         [ 90, 122, 187]],
#
#        [[128, 128, 128],
#         [129, 127, 133],
#         [126, 128, 129],
#         ...,
#         [ 89, 118, 185],
#         [ 88, 120, 186],
#         [ 88, 120, 185]],
#
#        [[127, 127, 127],
#         [128, 126, 132],
#         [125, 127, 128],
#         ...,
#         [ 87, 116, 183],
#         [ 86, 118, 184],
#         [ 86, 118, 183]]], dtype=uint8)
# orig_shape: (667, 1000)
# path: 'c:\\Users\\happy\\Desktop\\camera_ObjectDetection\\전면카메라\\YOLOv8\\selfie.jpg'
# probs: None
# save_dir: 'C:\\Users\\happy\\runs\\detect\\predict'
# speed: {'preprocess': 3.5674571990966797, 'inference': 342.3340320587158, 'postprocess': 1.764059066772461}

# %%
import time
import numpy as np
import mediapipe as mp
import cv2
from ultralytics import YOLO
from src.utils import intersection_over_union
from src.elements import face_detect, head_Pose
import torch
from torchvision.transforms import functional as F

from gtts import gTTS
import pygame
import tempfile
import threading
import os

import pyttsx3
import threading
engine = pyttsx3.init()

def speak(text):
    engine.say(text)
    engine.runAndWait()

# Check if CUDA is available and set the device accordingly
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

# Load Detection model & facemesh
# coco128 = open('camera_ObjectDetection\yolov8\coco128.txt', 'r')
# data = coco128.read()
# class_list = data.split('\n')
# coco128.close()
class_list = ['FACE']

model = YOLO('./best.pt')
model.to(device)  # Use the device set above

mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# Camera setting
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

# Hyperparameter setting
CONFIDENCE_THRESHOLD = 0.5
iou_threshold = 0.7
stable_threshold_time = 1.7
pct_threshold = 10

# Constants
GREEN = (0, 255, 0)
WHITE = (255, 255, 255)
BLUE = (0, 0, 255)

last_change_time = time.time()
last_bbox = None
max_area = 0
max_box = None

original_dim = (1280, 720)
resize_dim = (640, 640)
# Scale factors for coordinates
x_scale = original_dim[0] / resize_dim[0]
y_scale = original_dim[1] / resize_dim[1]

# 말을 한번만 하기 위해서 상태를 나타내는 변수 도입 -> 1일 때만 말해줄거야
state_loc_variable = 1

# Detection loop
while True:
    start = time.time()
    success, frame = cap.read()
    
    if not success:
        print('Cam Error')
        break
    
    # Head pose estimation
    headpose = head_Pose(image=frame, face_mesh=face_mesh)
    # Left/Right Inversion
    frame = cv2.flip(frame, 1)
    cv2.putText(frame, headpose, (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.5, GREEN, 2)
    
    # Convert resized frame to tensor and move to the same device as the model
    frame_resized = cv2.resize(frame, (640, 640))
    frame_tensor = F.to_tensor(frame_resized).unsqueeze(0).to(device)

    # Use the model for prediction
    detection = model.predict(frame_tensor, conf=CONFIDENCE_THRESHOLD)[0].cpu()

    # 모든 박스 검사 -> 최대 박스 선정
    for data in detection.boxes.data.tolist():
        xmin, ymin, xmax, ymax, conf, label = int(data[0]), int(data[1]), int(data[2]), int(data[3]), float(data[4]), int(data[5])
        xmin = int(xmin * x_scale)
        ymin = int(ymin * y_scale)
        xmax = int(xmax * x_scale)
        ymax = int(ymax * y_scale)

        # Calculate area of the box
        area = (xmax - xmin) * (ymax - ymin)

        # Check if this box is bigger than the previously found ones
        if area > max_area and label == 0:
            max_area = area
            max_box = [xmin, ymin, xmax, ymax, conf, label]

    # 조건을 충족하는 가장 큰 박스에서 작업 수행
    if max_box:
        xmin, ymin, xmax, ymax, conf, label = max_box
        new_bbox = [xmin, ymin, xmax, ymax]
        cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), (0, 255, 0), 2)  # GREEN
        cv2.putText(frame, f"{class_list[label]} {round(conf, 2)}", (xmin, ymin - 10), cv2.FONT_ITALIC, 1, (255, 255, 255), 2)  # WHITE

        if last_bbox is not None:
            iou = intersection_over_union(last_bbox, new_bbox)
            if iou < iou_threshold:
                last_change_time = time.time()
                state_loc_variable = 1
                # voice_assistant.shutdown()
            elif (time.time() - last_change_time) > stable_threshold_time and state_loc_variable == 1:
                pct, loc = face_detect(xmin, ymin, xmax, ymax, frame)
                #if pct > pct_threshold:
                text = f"현재 얼굴 비중은 {pct}%이고 얼굴 위치는 {loc}입니다."
                speak(text)
                last_change_time = time.time()
                state_loc_variable = 0

        last_bbox = new_bbox
    
    max_area = 0
    max_box = None
    
    # FPS calculation
    end = time.time()
    totalTime = end - start
    fps = f'FPS: {1 / totalTime:.2f}'
    print(f'Time to process 1 frame: {totalTime * 1000:.0f} milliseconds')
    print(fps)

    cv2.putText(frame, fps, (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, BLUE, 2)
    cv2.imshow('frame', frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Using device: cpu
#
# 0: 640x640 (no detections), 489.8ms
# Speed: 0.0ms preprocess, 489.8ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 1203 milliseconds
# FPS: 0.83
#
# 0: 640x640 1 FACE, 535.2ms
# Speed: 0.0ms preprocess, 535.2ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 598 milliseconds
# FPS: 1.67
#
# 0: 640x640 1 FACE, 462.1ms
# Speed: 0.0ms preprocess, 462.1ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 507 milliseconds
# FPS: 1.97
#
# 0: 640x640 1 FACE, 471.7ms
# Speed: 0.0ms preprocess, 471.7ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 518 milliseconds
# FPS: 1.93
#
# 0: 640x640 1 FACE, 437.0ms
# Speed: 0.0ms preprocess, 437.0ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 481 milliseconds
# FPS: 2.08
#
# 0: 640x640 1 FACE, 445.5ms
# Speed: 0.0ms preprocess, 445.5ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 482 milliseconds
# FPS: 2.08
#
# 0: 640x640 1 FACE, 469.3ms
# Speed: 0.0ms preprocess, 469.3ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 505 milliseconds
# FPS: 1.98
#
# 0: 640x640 1 FACE, 464.9ms
# Speed: 0.0ms preprocess, 464.9ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 500 milliseconds
# FPS: 2.00
#
# 0: 640x640 1 FACE, 438.3ms
# Speed: 0.0ms preprocess, 438.3ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 475 milliseconds
# FPS: 2.11
#
# 0: 640x640 1 FACE, 461.7ms
# Speed: 0.0ms preprocess, 461.7ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 499 milliseconds
# FPS: 2.00
#
# 0: 640x640 (no detections), 411.1ms
# Speed: 0.0ms preprocess, 411.1ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 445 milliseconds
# FPS: 2.25
#
# 0: 640x640 1 FACE, 427.4ms
# Speed: 0.0ms preprocess, 427.4ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 466 milliseconds
# FPS: 2.14
#
# 0: 640x640 1 FACE, 448.3ms
# Speed: 0.0ms preprocess, 448.3ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 490 milliseconds
# FPS: 2.04
#
# 0: 640x640 1 FACE, 441.9ms
# Speed: 0.0ms preprocess, 441.9ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 476 milliseconds
# FPS: 2.10
#
# 0: 640x640 1 FACE, 449.3ms
# Speed: 0.0ms preprocess, 449.3ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 485 milliseconds
# FPS: 2.06
#
# 0: 640x640 1 FACE, 434.0ms
# Speed: 0.0ms preprocess, 434.0ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 468 milliseconds
# FPS: 2.13
#
# 0: 640x640 1 FACE, 431.4ms
# Speed: 0.0ms preprocess, 431.4ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 470 milliseconds
# FPS: 2.13
#
# 0: 640x640 1 FACE, 412.7ms
# Speed: 0.0ms preprocess, 412.7ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 452 milliseconds
# FPS: 2.21
#
# 0: 640x640 1 FACE, 445.0ms
# Speed: 0.0ms preprocess, 445.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 477 milliseconds
# FPS: 2.10
#
# 0: 640x640 1 FACE, 468.1ms
# Speed: 0.0ms preprocess, 468.1ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 506 milliseconds
# FPS: 1.98
#
# 0: 640x640 1 FACE, 432.8ms
# Speed: 0.0ms preprocess, 432.8ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 474 milliseconds
# FPS: 2.11
#
# 0: 640x640 1 FACE, 440.9ms
# Speed: 0.0ms preprocess, 440.9ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 477 milliseconds
# FPS: 2.10
#
# 0: 640x640 1 FACE, 456.5ms
# Speed: 0.0ms preprocess, 456.5ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 489 milliseconds
# FPS: 2.05
#
# 0: 640x640 1 FACE, 432.5ms
# Speed: 0.0ms preprocess, 432.5ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 468 milliseconds
# FPS: 2.14
#
# 0: 640x640 1 FACE, 434.4ms
# Speed: 0.0ms preprocess, 434.4ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 478 milliseconds
# FPS: 2.09
#
# 0: 640x640 1 FACE, 446.4ms
# Speed: 0.0ms preprocess, 446.4ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 486 milliseconds
# FPS: 2.06
#
# 0: 640x640 1 FACE, 449.3ms
# Speed: 0.0ms preprocess, 449.3ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 488 milliseconds
# FPS: 2.05
#
# 0: 640x640 1 FACE, 471.1ms
# Speed: 0.0ms preprocess, 471.1ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 509 milliseconds
# FPS: 1.96
#
# 0: 640x640 1 FACE, 466.1ms
# Speed: 0.0ms preprocess, 466.1ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 5179 milliseconds
# FPS: 0.19
#
# 0: 640x640 1 FACE, 511.4ms
# Speed: 0.0ms preprocess, 511.4ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 547 milliseconds
# FPS: 1.83
#
# 0: 640x640 1 FACE, 496.4ms
# Speed: 0.0ms preprocess, 496.4ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 537 milliseconds
# FPS: 1.86
#
# 0: 640x640 1 FACE, 470.5ms
# Speed: 0.0ms preprocess, 470.5ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 512 milliseconds
# FPS: 1.95
#
# 0: 640x640 1 FACE, 472.7ms
# Speed: 0.0ms preprocess, 472.7ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 513 milliseconds
# FPS: 1.95
#
# 0: 640x640 1 FACE, 443.7ms
# Speed: 0.0ms preprocess, 443.7ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 476 milliseconds
# FPS: 2.10
#
# 0: 640x640 1 FACE, 448.1ms
# Speed: 0.0ms preprocess, 448.1ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 485 milliseconds
# FPS: 2.06
#
# 0: 640x640 1 FACE, 446.9ms
# Speed: 0.0ms preprocess, 446.9ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 4949 milliseconds
# FPS: 0.20
#
# 0: 640x640 1 FACE, 516.7ms
# Speed: 0.0ms preprocess, 516.7ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 562 milliseconds
# FPS: 1.78
#
# 0: 640x640 1 FACE, 447.6ms
# Speed: 0.0ms preprocess, 447.6ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 493 milliseconds
# FPS: 2.03
#
# 0: 640x640 1 FACE, 456.2ms
# Speed: 0.0ms preprocess, 456.2ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 494 milliseconds
# FPS: 2.03
#
# 0: 640x640 1 FACE, 478.4ms
# Speed: 0.0ms preprocess, 478.4ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 516 milliseconds
# FPS: 1.94
#
# 0: 640x640 1 FACE, 469.1ms
# Speed: 0.0ms preprocess, 469.1ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 4976 milliseconds
# FPS: 0.20
#
# 0: 640x640 1 FACE, 500.2ms
# Speed: 0.0ms preprocess, 500.2ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 547 milliseconds
# FPS: 1.83
#
# 0: 640x640 1 FACE, 469.9ms
# Speed: 0.0ms preprocess, 469.9ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 505 milliseconds
# FPS: 1.98
#
# 0: 640x640 1 FACE, 459.1ms
# Speed: 0.0ms preprocess, 459.1ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 500 milliseconds
# FPS: 2.00
#
# 0: 640x640 1 FACE, 482.9ms
# Speed: 0.0ms preprocess, 482.9ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 519 milliseconds
# FPS: 1.93
#
# 0: 640x640 1 FACE, 434.4ms
# Speed: 1.0ms preprocess, 434.4ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 471 milliseconds
# FPS: 2.12
#
# 0: 640x640 1 FACE, 497.2ms
# Speed: 0.0ms preprocess, 497.2ms inference, 15.8ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 545 milliseconds
# FPS: 1.83
#
# 0: 640x640 1 FACE, 503.3ms
# Speed: 0.0ms preprocess, 503.3ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 5020 milliseconds
# FPS: 0.20
#
# 0: 640x640 1 FACE, 482.1ms
# Speed: 0.0ms preprocess, 482.1ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 528 milliseconds
# FPS: 1.90
#
# 0: 640x640 1 FACE, 461.7ms
# Speed: 0.0ms preprocess, 461.7ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 497 milliseconds
# FPS: 2.01
#
# 0: 640x640 1 FACE, 492.1ms
# Speed: 0.0ms preprocess, 492.1ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 527 milliseconds
# FPS: 1.90
#
# 0: 640x640 (no detections), 469.3ms
# Speed: 0.0ms preprocess, 469.3ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 502 milliseconds
# FPS: 1.99
#
# 0: 640x640 (no detections), 492.6ms
# Speed: 0.0ms preprocess, 492.6ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 526 milliseconds
# FPS: 1.90
#
# 0: 640x640 (no detections), 448.4ms
# Speed: 0.0ms preprocess, 448.4ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 478 milliseconds
# FPS: 2.09
#
# 0: 640x640 (no detections), 447.6ms
# Speed: 0.0ms preprocess, 447.6ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 482 milliseconds
# FPS: 2.07
#
# 0: 640x640 (no detections), 455.9ms
# Speed: 0.0ms preprocess, 455.9ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 491 milliseconds
# FPS: 2.04
#
# 0: 640x640 (no detections), 451.8ms
# Speed: 0.0ms preprocess, 451.8ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 484 milliseconds
# FPS: 2.07
#
# 0: 640x640 (no detections), 428.4ms
# Speed: 0.0ms preprocess, 428.4ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 465 milliseconds
# FPS: 2.15
#
# 0: 640x640 1 FACE, 432.4ms
# Speed: 0.0ms preprocess, 432.4ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 468 milliseconds
# FPS: 2.13
#
# 0: 640x640 1 FACE, 481.8ms
# Speed: 0.0ms preprocess, 481.8ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 512 milliseconds
# FPS: 1.95
#
# 0: 640x640 1 FACE, 465.9ms
# Speed: 0.0ms preprocess, 465.9ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 504 milliseconds
# FPS: 1.98
#
# 0: 640x640 1 FACE, 456.2ms
# Speed: 0.0ms preprocess, 456.2ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 493 milliseconds
# FPS: 2.03
#
# 0: 640x640 1 FACE, 434.7ms
# Speed: 0.0ms preprocess, 434.7ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 471 milliseconds
# FPS: 2.12
#
# 0: 640x640 1 FACE, 445.2ms
# Speed: 0.0ms preprocess, 445.2ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 480 milliseconds
# FPS: 2.08
#
# 0: 640x640 1 FACE, 449.4ms
# Speed: 0.0ms preprocess, 449.4ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 490 milliseconds
# FPS: 2.04
#
# 0: 640x640 1 FACE, 437.4ms
# Speed: 0.0ms preprocess, 437.4ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 481 milliseconds
# FPS: 2.08
#
# 0: 640x640 1 FACE, 449.7ms
# Speed: 0.0ms preprocess, 449.7ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 485 milliseconds
# FPS: 2.06
#
# 0: 640x640 1 FACE, 468.6ms
# Speed: 0.0ms preprocess, 468.6ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 509 milliseconds
# FPS: 1.97
#
# 0: 640x640 1 FACE, 459.5ms
# Speed: 0.0ms preprocess, 459.5ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 492 milliseconds
# FPS: 2.03
#
# 0: 640x640 1 FACE, 438.4ms
# Speed: 0.0ms preprocess, 438.4ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 476 milliseconds
# FPS: 2.10
#
# 0: 640x640 1 FACE, 459.8ms
# Speed: 0.0ms preprocess, 459.8ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 490 milliseconds
# FPS: 2.04
#
# 0: 640x640 1 FACE, 444.5ms
# Speed: 0.0ms preprocess, 444.5ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 487 milliseconds
# FPS: 2.05
#
# 0: 640x640 1 FACE, 435.5ms
# Speed: 0.0ms preprocess, 435.5ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 474 milliseconds
# FPS: 2.11
#
# 0: 640x640 1 FACE, 469.0ms
# Speed: 0.0ms preprocess, 469.0ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 506 milliseconds
# FPS: 1.98
#
# 0: 640x640 1 FACE, 435.9ms
# Speed: 0.0ms preprocess, 435.9ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 473 milliseconds
# FPS: 2.11
#
# 0: 640x640 1 FACE, 487.0ms
# Speed: 0.0ms preprocess, 487.0ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 520 milliseconds
# FPS: 1.92
#
# 0: 640x640 1 FACE, 457.3ms
# Speed: 0.0ms preprocess, 457.3ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 493 milliseconds
# FPS: 2.03
#
# 0: 640x640 1 FACE, 466.1ms
# Speed: 0.0ms preprocess, 466.1ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 501 milliseconds
# FPS: 2.00
#
# 0: 640x640 1 FACE, 436.8ms
# Speed: 0.0ms preprocess, 436.8ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 473 milliseconds
# FPS: 2.11
#
# 0: 640x640 1 FACE, 432.0ms
# Speed: 0.0ms preprocess, 432.0ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 471 milliseconds
# FPS: 2.12
#
# 0: 640x640 1 FACE, 453.7ms
# Speed: 0.0ms preprocess, 453.7ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 490 milliseconds
# FPS: 2.04
#
# 0: 640x640 1 FACE, 607.9ms
# Speed: 0.0ms preprocess, 607.9ms inference, 13.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 659 milliseconds
# FPS: 1.52
#
# 0: 640x640 1 FACE, 470.1ms
# Speed: 0.0ms preprocess, 470.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 509 milliseconds
# FPS: 1.96
#
# 0: 640x640 1 FACE, 426.2ms
# Speed: 0.0ms preprocess, 426.2ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 463 milliseconds
# FPS: 2.16
#
# 0: 640x640 1 FACE, 437.9ms
# Speed: 0.0ms preprocess, 437.9ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 473 milliseconds
# FPS: 2.12
#
# 0: 640x640 1 FACE, 448.2ms
# Speed: 0.0ms preprocess, 448.2ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 489 milliseconds
# FPS: 2.04
#
# 0: 640x640 1 FACE, 464.1ms
# Speed: 0.0ms preprocess, 464.1ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 497 milliseconds
# FPS: 2.01
#
# 0: 640x640 1 FACE, 426.0ms
# Speed: 0.0ms preprocess, 426.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 458 milliseconds
# FPS: 2.18
#
# 0: 640x640 1 FACE, 446.5ms
# Speed: 0.0ms preprocess, 446.5ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 483 milliseconds
# FPS: 2.07
#
# 0: 640x640 1 FACE, 448.9ms
# Speed: 0.0ms preprocess, 448.9ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 483 milliseconds
# FPS: 2.07
#
# 0: 640x640 1 FACE, 450.8ms
# Speed: 0.0ms preprocess, 450.8ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 482 milliseconds
# FPS: 2.08
#
# 0: 640x640 1 FACE, 430.9ms
# Speed: 0.0ms preprocess, 430.9ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 467 milliseconds
# FPS: 2.14
#
# 0: 640x640 1 FACE, 449.6ms
# Speed: 0.0ms preprocess, 449.6ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 485 milliseconds
# FPS: 2.06
#
# 0: 640x640 1 FACE, 468.5ms
# Speed: 0.0ms preprocess, 468.5ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 503 milliseconds
# FPS: 1.99
#
# 0: 640x640 1 FACE, 430.8ms
# Speed: 0.0ms preprocess, 430.8ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 463 milliseconds
# FPS: 2.16
#
# 0: 640x640 1 FACE, 448.9ms
# Speed: 0.0ms preprocess, 448.9ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 484 milliseconds
# FPS: 2.07
#
# 0: 640x640 1 FACE, 417.8ms
# Speed: 0.0ms preprocess, 417.8ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 451 milliseconds
# FPS: 2.22
#
# 0: 640x640 1 FACE, 442.3ms
# Speed: 0.0ms preprocess, 442.3ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 478 milliseconds
# FPS: 2.09
#
# 0: 640x640 1 FACE, 442.6ms
# Speed: 0.0ms preprocess, 442.6ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 475 milliseconds
# FPS: 2.10
#
# 0: 640x640 1 FACE, 448.7ms
# Speed: 0.0ms preprocess, 448.7ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 485 milliseconds
# FPS: 2.06
#
# 0: 640x640 1 FACE, 434.1ms
# Speed: 0.0ms preprocess, 434.1ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 472 milliseconds
# FPS: 2.12
#
# 0: 640x640 1 FACE, 449.9ms
# Speed: 0.0ms preprocess, 449.9ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 486 milliseconds
# FPS: 2.06
#
# 0: 640x640 1 FACE, 469.5ms
# Speed: 0.0ms preprocess, 469.5ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 508 milliseconds
# FPS: 1.97
#
# 0: 640x640 1 FACE, 447.4ms
# Speed: 0.0ms preprocess, 447.4ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 484 milliseconds
# FPS: 2.07
#
# 0: 640x640 1 FACE, 440.5ms
# Speed: 0.0ms preprocess, 440.5ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 479 milliseconds
# FPS: 2.09
#
# 0: 640x640 1 FACE, 448.9ms
# Speed: 0.0ms preprocess, 448.9ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 486 milliseconds
# FPS: 2.06
#
# 0: 640x640 1 FACE, 460.7ms
# Speed: 0.0ms preprocess, 460.7ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 493 milliseconds
# FPS: 2.03
#
# 0: 640x640 1 FACE, 432.0ms
# Speed: 0.0ms preprocess, 432.0ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 463 milliseconds
# FPS: 2.16
#
# 0: 640x640 1 FACE, 434.6ms
# Speed: 0.0ms preprocess, 434.6ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 467 milliseconds
# FPS: 2.14
#
# 0: 640x640 1 FACE, 440.3ms
# Speed: 0.0ms preprocess, 440.3ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 476 milliseconds
# FPS: 2.10
#
# 0: 640x640 1 FACE, 432.8ms
# Speed: 0.0ms preprocess, 432.8ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 472 milliseconds
# FPS: 2.12
#
# 0: 640x640 1 FACE, 438.5ms
# Speed: 0.0ms preprocess, 438.5ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 474 milliseconds
# FPS: 2.11
#
# 0: 640x640 1 FACE, 451.0ms
# Speed: 0.0ms preprocess, 451.0ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 486 milliseconds
# FPS: 2.06
#
# 0: 640x640 1 FACE, 460.3ms
# Speed: 0.0ms preprocess, 460.3ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 496 milliseconds
# FPS: 2.01
#
# 0: 640x640 1 FACE, 436.2ms
# Speed: 0.0ms preprocess, 436.2ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 473 milliseconds
# FPS: 2.11
#
# 0: 640x640 1 FACE, 437.6ms
# Speed: 0.0ms preprocess, 437.6ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 473 milliseconds
# FPS: 2.11
#
# 0: 640x640 1 FACE, 453.0ms
# Speed: 0.0ms preprocess, 453.0ms inference, 8.8ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 491 milliseconds
# FPS: 2.04
#
# 0: 640x640 1 FACE, 428.9ms
# Speed: 0.0ms preprocess, 428.9ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 467 milliseconds
# FPS: 2.14
#
# 0: 640x640 1 FACE, 444.7ms
# Speed: 0.0ms preprocess, 444.7ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 481 milliseconds
# FPS: 2.08
#
# 0: 640x640 1 FACE, 463.0ms
# Speed: 0.0ms preprocess, 463.0ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 492 milliseconds
# FPS: 2.03
#
# 0: 640x640 1 FACE, 435.9ms
# Speed: 0.0ms preprocess, 435.9ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 471 milliseconds
# FPS: 2.12
#
# 0: 640x640 1 FACE, 442.0ms
# Speed: 0.0ms preprocess, 442.0ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 476 milliseconds
# FPS: 2.10
#
# 0: 640x640 1 FACE, 408.0ms
# Speed: 0.0ms preprocess, 408.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 439 milliseconds
# FPS: 2.28
#
# 0: 640x640 1 FACE, 441.3ms
# Speed: 0.0ms preprocess, 441.3ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 480 milliseconds
# FPS: 2.08
#
# 0: 640x640 1 FACE, 450.5ms
# Speed: 0.0ms preprocess, 450.5ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 485 milliseconds
# FPS: 2.06
#
# 0: 640x640 1 FACE, 452.7ms
# Speed: 0.0ms preprocess, 452.7ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 492 milliseconds
# FPS: 2.03
#
# 0: 640x640 1 FACE, 453.2ms
# Speed: 0.0ms preprocess, 453.2ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 488 milliseconds
# FPS: 2.05
#
# 0: 640x640 1 FACE, 440.3ms
# Speed: 0.0ms preprocess, 440.3ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 470 milliseconds
# FPS: 2.13
#
# 0: 640x640 1 FACE, 457.6ms
# Speed: 0.0ms preprocess, 457.6ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 491 milliseconds
# FPS: 2.04
#
# 0: 640x640 1 FACE, 449.3ms
# Speed: 0.0ms preprocess, 449.3ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 486 milliseconds
# FPS: 2.06
#
# 0: 640x640 1 FACE, 437.4ms
# Speed: 0.0ms preprocess, 437.4ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 477 milliseconds
# FPS: 2.10
#
# 0: 640x640 1 FACE, 496.7ms
# Speed: 0.0ms preprocess, 496.7ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 537 milliseconds
# FPS: 1.86
#
# 0: 640x640 1 FACE, 450.0ms
# Speed: 0.0ms preprocess, 450.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 494 milliseconds
# FPS: 2.02
#
# 0: 640x640 1 FACE, 496.3ms
# Speed: 0.0ms preprocess, 496.3ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 531 milliseconds
# FPS: 1.88
#
# 0: 640x640 1 FACE, 437.6ms
# Speed: 0.0ms preprocess, 437.6ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 468 milliseconds
# FPS: 2.14
#
# 0: 640x640 1 FACE, 454.9ms
# Speed: 0.0ms preprocess, 454.9ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 490 milliseconds
# FPS: 2.04
#
# 0: 640x640 1 FACE, 451.2ms
# Speed: 0.0ms preprocess, 451.2ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 484 milliseconds
# FPS: 2.07
#
# 0: 640x640 1 FACE, 447.0ms
# Speed: 0.0ms preprocess, 447.0ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 483 milliseconds
# FPS: 2.07
#
# 0: 640x640 1 FACE, 471.1ms
# Speed: 0.0ms preprocess, 471.1ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 510 milliseconds
# FPS: 1.96
#
# 0: 640x640 1 FACE, 452.6ms
# Speed: 0.0ms preprocess, 452.6ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 490 milliseconds
# FPS: 2.04
#
# 0: 640x640 1 FACE, 488.0ms
# Speed: 0.0ms preprocess, 488.0ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 526 milliseconds
# FPS: 1.90
#
# 0: 640x640 2 FACEs, 418.5ms
# Speed: 0.0ms preprocess, 418.5ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 452 milliseconds
# FPS: 2.21
#
# 0: 640x640 2 FACEs, 483.7ms
# Speed: 0.0ms preprocess, 483.7ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 517 milliseconds
# FPS: 1.93
#
# 0: 640x640 3 FACEs, 426.1ms
# Speed: 0.0ms preprocess, 426.1ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 462 milliseconds
# FPS: 2.17
#
# 0: 640x640 2 FACEs, 474.6ms
# Speed: 0.0ms preprocess, 474.6ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 4905 milliseconds
# FPS: 0.20
#
# 0: 640x640 2 FACEs, 534.6ms
# Speed: 0.0ms preprocess, 534.6ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 577 milliseconds
# FPS: 1.73
#
# 0: 640x640 1 FACE, 528.7ms
# Speed: 0.0ms preprocess, 528.7ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 575 milliseconds
# FPS: 1.74
#
# 0: 640x640 2 FACEs, 480.4ms
# Speed: 0.0ms preprocess, 480.4ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 532 milliseconds
# FPS: 1.88
#
# 0: 640x640 1 FACE, 471.8ms
# Speed: 0.0ms preprocess, 471.8ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 512 milliseconds
# FPS: 1.95
#
# 0: 640x640 1 FACE, 468.9ms
# Speed: 0.0ms preprocess, 468.9ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 510 milliseconds
# FPS: 1.96
#
# 0: 640x640 2 FACEs, 419.4ms
# Speed: 0.0ms preprocess, 419.4ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 459 milliseconds
# FPS: 2.18
#
# 0: 640x640 2 FACEs, 429.6ms
# Speed: 0.0ms preprocess, 429.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 468 milliseconds
# FPS: 2.14
#
# 0: 640x640 2 FACEs, 457.0ms
# Speed: 0.0ms preprocess, 457.0ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 493 milliseconds
# FPS: 2.03
#
# 0: 640x640 3 FACEs, 466.6ms
# Speed: 0.0ms preprocess, 466.6ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 501 milliseconds
# FPS: 2.00
#
# 0: 640x640 3 FACEs, 449.1ms
# Speed: 0.0ms preprocess, 449.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 485 milliseconds
# FPS: 2.06
#
# 0: 640x640 2 FACEs, 455.1ms
# Speed: 0.0ms preprocess, 455.1ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 489 milliseconds
# FPS: 2.05
#
# 0: 640x640 2 FACEs, 439.1ms
# Speed: 0.0ms preprocess, 439.1ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 472 milliseconds
# FPS: 2.12
#
# 0: 640x640 2 FACEs, 437.4ms
# Speed: 0.0ms preprocess, 437.4ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 474 milliseconds
# FPS: 2.11
#
# 0: 640x640 1 FACE, 430.2ms
# Speed: 0.0ms preprocess, 430.2ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 466 milliseconds
# FPS: 2.14
#
# 0: 640x640 2 FACEs, 471.6ms
# Speed: 0.0ms preprocess, 471.6ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 506 milliseconds
# FPS: 1.98
#
# 0: 640x640 2 FACEs, 514.5ms
# Speed: 0.0ms preprocess, 514.5ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 551 milliseconds
# FPS: 1.81
#
# 0: 640x640 2 FACEs, 459.9ms
# Speed: 0.0ms preprocess, 459.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 496 milliseconds
# FPS: 2.02
#
# 0: 640x640 1 FACE, 457.0ms
# Speed: 0.0ms preprocess, 457.0ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 492 milliseconds
# FPS: 2.03
#
# 0: 640x640 (no detections), 432.8ms
# Speed: 0.0ms preprocess, 432.8ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 465 milliseconds
# FPS: 2.15
#
# 0: 640x640 (no detections), 445.5ms
# Speed: 0.0ms preprocess, 445.5ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 485 milliseconds
# FPS: 2.06
#
# 0: 640x640 (no detections), 461.5ms
# Speed: 0.0ms preprocess, 461.5ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 498 milliseconds
# FPS: 2.01
#
# 0: 640x640 1 FACE, 446.0ms
# Speed: 0.0ms preprocess, 446.0ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 489 milliseconds
# FPS: 2.05
#
# 0: 640x640 1 FACE, 464.7ms
# Speed: 0.0ms preprocess, 464.7ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 510 milliseconds
# FPS: 1.96
#
# 0: 640x640 2 FACEs, 465.0ms
# Speed: 0.0ms preprocess, 465.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 508 milliseconds
# FPS: 1.97
#
# 0: 640x640 (no detections), 444.1ms
# Speed: 0.0ms preprocess, 444.1ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 476 milliseconds
# FPS: 2.10
#
# 0: 640x640 (no detections), 443.6ms
# Speed: 0.0ms preprocess, 443.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 478 milliseconds
# FPS: 2.09
#
# 0: 640x640 (no detections), 436.3ms
# Speed: 0.0ms preprocess, 436.3ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 462 milliseconds
# FPS: 2.16
#
# 0: 640x640 2 FACEs, 409.8ms
# Speed: 0.0ms preprocess, 409.8ms inference, 8.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 441 milliseconds
# FPS: 2.27
#
# 0: 640x640 (no detections), 458.1ms
# Speed: 0.0ms preprocess, 458.1ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 502 milliseconds
# FPS: 1.99
#
# 0: 640x640 (no detections), 492.7ms
# Speed: 0.0ms preprocess, 492.7ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 534 milliseconds
# FPS: 1.87
#
# 0: 640x640 (no detections), 432.7ms
# Speed: 0.0ms preprocess, 432.7ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 469 milliseconds
# FPS: 2.13
#
# 0: 640x640 (no detections), 422.3ms
# Speed: 0.0ms preprocess, 422.3ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 455 milliseconds
# FPS: 2.20
#
# 0: 640x640 (no detections), 449.8ms
# Speed: 0.0ms preprocess, 449.8ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 483 milliseconds
# FPS: 2.07
#
# 0: 640x640 (no detections), 469.8ms
# Speed: 0.0ms preprocess, 469.8ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 504 milliseconds
# FPS: 1.98
#
# 0: 640x640 1 FACE, 468.6ms
# Speed: 0.0ms preprocess, 468.6ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 505 milliseconds
# FPS: 1.98
#
# 0: 640x640 (no detections), 470.1ms
# Speed: 0.0ms preprocess, 470.1ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 507 milliseconds
# FPS: 1.97
#
# 0: 640x640 2 FACEs, 483.2ms
# Speed: 0.0ms preprocess, 483.2ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 521 milliseconds
# FPS: 1.92
#
# 0: 640x640 1 FACE, 445.8ms
# Speed: 0.0ms preprocess, 445.8ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 481 milliseconds
# FPS: 2.08
#
# 0: 640x640 (no detections), 442.6ms
# Speed: 0.0ms preprocess, 442.6ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 474 milliseconds
# FPS: 2.11
#
# 0: 640x640 (no detections), 425.3ms
# Speed: 0.0ms preprocess, 425.3ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 457 milliseconds
# FPS: 2.19
#
# 0: 640x640 (no detections), 424.3ms
# Speed: 0.0ms preprocess, 424.3ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 460 milliseconds
# FPS: 2.17
#
# 0: 640x640 (no detections), 461.0ms
# Speed: 0.0ms preprocess, 461.0ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 495 milliseconds
# FPS: 2.02
#
# 0: 640x640 (no detections), 496.3ms
# Speed: 0.0ms preprocess, 496.3ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 533 milliseconds
# FPS: 1.87
#
# 0: 640x640 (no detections), 425.4ms
# Speed: 0.0ms preprocess, 425.4ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 459 milliseconds
# FPS: 2.18
#
# 0: 640x640 (no detections), 430.8ms
# Speed: 0.0ms preprocess, 430.8ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 465 milliseconds
# FPS: 2.15
#
# 0: 640x640 (no detections), 426.1ms
# Speed: 0.0ms preprocess, 426.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 459 milliseconds
# FPS: 2.18
#
# 0: 640x640 (no detections), 468.6ms
# Speed: 0.0ms preprocess, 468.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 502 milliseconds
# FPS: 1.99
#
# 0: 640x640 (no detections), 456.9ms
# Speed: 0.0ms preprocess, 456.9ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 489 milliseconds
# FPS: 2.04
#
# 0: 640x640 1 FACE, 424.7ms
# Speed: 0.0ms preprocess, 424.7ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 456 milliseconds
# FPS: 2.19
#
# 0: 640x640 (no detections), 464.3ms
# Speed: 0.0ms preprocess, 464.3ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 494 milliseconds
# FPS: 2.02
#
# 0: 640x640 1 FACE, 429.2ms
# Speed: 0.0ms preprocess, 429.2ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 469 milliseconds
# FPS: 2.13
#
# 0: 640x640 1 FACE, 441.4ms
# Speed: 0.0ms preprocess, 441.4ms inference, 8.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 479 milliseconds
# FPS: 2.09
#
# 0: 640x640 (no detections), 564.1ms
# Speed: 0.0ms preprocess, 564.1ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 599 milliseconds
# FPS: 1.67
#
# 0: 640x640 3 FACEs, 461.0ms
# Speed: 0.0ms preprocess, 461.0ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 499 milliseconds
# FPS: 2.00
#
# 0: 640x640 1 FACE, 451.9ms
# Speed: 0.0ms preprocess, 451.9ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 490 milliseconds
# FPS: 2.04
#
# 0: 640x640 1 FACE, 485.2ms
# Speed: 0.0ms preprocess, 485.2ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 522 milliseconds
# FPS: 1.92
#
# 0: 640x640 1 FACE, 457.4ms
# Speed: 0.0ms preprocess, 457.4ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 492 milliseconds
# FPS: 2.03
#
# 0: 640x640 1 FACE, 474.0ms
# Speed: 0.0ms preprocess, 474.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 509 milliseconds
# FPS: 1.96
#
# 0: 640x640 1 FACE, 423.3ms
# Speed: 0.0ms preprocess, 423.3ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 5011 milliseconds
# FPS: 0.20
#
# 0: 640x640 1 FACE, 521.7ms
# Speed: 0.0ms preprocess, 521.7ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 570 milliseconds
# FPS: 1.75
#
# 0: 640x640 1 FACE, 494.5ms
# Speed: 0.0ms preprocess, 494.5ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 535 milliseconds
# FPS: 1.87
#
# 0: 640x640 1 FACE, 454.5ms
# Speed: 0.0ms preprocess, 454.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 492 milliseconds
# FPS: 2.03
#
# 0: 640x640 1 FACE, 476.2ms
# Speed: 0.0ms preprocess, 476.2ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 513 milliseconds
# FPS: 1.95
#
# 0: 640x640 1 FACE, 488.7ms
# Speed: 0.0ms preprocess, 488.7ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 529 milliseconds
# FPS: 1.89
#
# 0: 640x640 1 FACE, 503.4ms
# Speed: 1.0ms preprocess, 503.4ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 543 milliseconds
# FPS: 1.84
#
# 0: 640x640 1 FACE, 461.5ms
# Speed: 0.0ms preprocess, 461.5ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 501 milliseconds
# FPS: 2.00
#
# 0: 640x640 1 FACE, 470.5ms
# Speed: 0.0ms preprocess, 470.5ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 507 milliseconds
# FPS: 1.97

# %%
head_Pose('./selfie.jpg',face_mesh=face_mesh)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 head_Pose('./selfie.jpg',face_mesh=face_mesh)
#
# File c:\Users\happy\Desktop\camera_ObjectDetection\전면카메라\YOLOv8\src\elements.py:22, in head_Pose(image, face_mesh)
#      20 def head_Pose(image, face_mesh):
#      21     global text
# ---> 22     image = cv2.flip(image, 1)
#      23     image.flags.writeable = False
#      24     results = face_mesh.process(image)
#
# error: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'flip'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
import time
import numpy as np
import mediapipe as mp
import cv2
from ultralytics import YOLO
from src.utils import intersection_over_union
from src.elements import face_detect, head_Pose
import torch
from torchvision.transforms import functional as F

from gtts import gTTS
import pygame
import tempfile
import threading
import os

import pyttsx3
import threading
engine = pyttsx3.init()

def speak(text):
    engine.say(text)
    engine.runAndWait()

# Check if CUDA is available and set the device accordingly
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

# Load Detection model & facemesh
# coco128 = open('camera_ObjectDetection\yolov8\coco128.txt', 'r')
# data = coco128.read()
# class_list = data.split('\n')
# coco128.close()
class_list = ['FACE']

model = YOLO('./best.pt')
model.to(device)  # Use the device set above

mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# Camera setting
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

# Hyperparameter setting
CONFIDENCE_THRESHOLD = 0.5
iou_threshold = 0.7
stable_threshold_time = 1.7
pct_threshold = 10

# Constants
GREEN = (0, 255, 0)
WHITE = (255, 255, 255)
BLUE = (0, 0, 255)

last_change_time = time.time()
last_bbox = None
max_area = 0
max_box = None

original_dim = (1280, 720)
resize_dim = (640, 640)
# Scale factors for coordinates
x_scale = original_dim[0] / resize_dim[0]
y_scale = original_dim[1] / resize_dim[1]

# 말을 한번만 하기 위해서 상태를 나타내는 변수 도입 -> 1일 때만 말해줄거야
state_loc_variable = 1

# Detection loop
while True:
    start = time.time()
    success, frame = cap.read()
    
    if not success:
        print('Cam Error')
        break
    
    # Head pose estimation
    headpose = head_Pose(image=frame, face_mesh=face_mesh)
    # Left/Right Inversion
    frame = cv2.flip(frame, 1)
    cv2.putText(frame, headpose, (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.5, GREEN, 2)
    
    # Convert resized frame to tensor and move to the same device as the model
    frame_resized = cv2.resize(frame, (640, 640))
    frame_tensor = F.to_tensor(frame_resized).unsqueeze(0).to(device)

    # Use the model for prediction
    detection = model.predict(frame_tensor, conf=CONFIDENCE_THRESHOLD)[0].cpu()

    # 모든 박스 검사 -> 최대 박스 선정
    for data in detection.boxes.data.tolist():
        xmin, ymin, xmax, ymax, conf, label = int(data[0]), int(data[1]), int(data[2]), int(data[3]), float(data[4]), int(data[5])
        xmin = int(xmin * x_scale)
        ymin = int(ymin * y_scale)
        xmax = int(xmax * x_scale)
        ymax = int(ymax * y_scale)

    
        cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), (0, 255, 0), 2)  # GREEN
        cv2.putText(frame, f"{class_list[label]} {round(conf, 2)}", (xmin, ymin - 10), cv2.FONT_ITALIC, 1, (255, 255, 255), 2)  # WHITE


    
    # FPS calculation
    end = time.time()
    totalTime = end - start
    fps = f'FPS: {1 / totalTime:.2f}'
    print(f'Time to process 1 frame: {totalTime * 1000:.0f} milliseconds')
    print(fps)

    cv2.putText(frame, fps, (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, BLUE, 2)
    cv2.imshow('frame', frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.8.19)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Using device: cpu
#
# 0: 640x640 (no detections), 499.9ms
# Speed: 0.0ms preprocess, 499.9ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 2680 milliseconds
# FPS: 0.37
#
# 0: 640x640 1 FACE, 487.2ms
# Speed: 0.0ms preprocess, 487.2ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 529 milliseconds
# FPS: 1.89
#
# 0: 640x640 1 FACE, 430.6ms
# Speed: 0.0ms preprocess, 430.6ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 469 milliseconds
# FPS: 2.13
#
# 0: 640x640 1 FACE, 486.4ms
# Speed: 0.0ms preprocess, 486.4ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 529 milliseconds
# FPS: 1.89
#
# 0: 640x640 1 FACE, 537.3ms
# Speed: 0.0ms preprocess, 537.3ms inference, 7.6ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 585 milliseconds
# FPS: 1.71
#
# 0: 640x640 1 FACE, 458.7ms
# Speed: 0.0ms preprocess, 458.7ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 500 milliseconds
# FPS: 2.00
#
# 0: 640x640 1 FACE, 548.7ms
# Speed: 0.0ms preprocess, 548.7ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 592 milliseconds
# FPS: 1.69
#
# 0: 640x640 1 FACE, 573.7ms
# Speed: 0.0ms preprocess, 573.7ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 615 milliseconds
# FPS: 1.63
#
# 0: 640x640 1 FACE, 446.6ms
# Speed: 0.0ms preprocess, 446.6ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 499 milliseconds
# FPS: 2.01
#
# 0: 640x640 1 FACE, 529.7ms
# Speed: 0.0ms preprocess, 529.7ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 570 milliseconds
# FPS: 1.76
#
# 0: 640x640 1 FACE, 476.1ms
# Speed: 0.0ms preprocess, 476.1ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 517 milliseconds
# FPS: 1.93
#
# 0: 640x640 1 FACE, 474.3ms
# Speed: 0.0ms preprocess, 474.3ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 509 milliseconds
# FPS: 1.96
#
# 0: 640x640 1 FACE, 441.0ms
# Speed: 0.0ms preprocess, 441.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 476 milliseconds
# FPS: 2.10
#
# 0: 640x640 (no detections), 414.7ms
# Speed: 1.0ms preprocess, 414.7ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 453 milliseconds
# FPS: 2.21
#
# 0: 640x640 (no detections), 414.1ms
# Speed: 0.0ms preprocess, 414.1ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 457 milliseconds
# FPS: 2.19
#
# 0: 640x640 1 FACE, 426.6ms
# Speed: 0.0ms preprocess, 426.6ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 461 milliseconds
# FPS: 2.17
#
# 0: 640x640 1 FACE, 470.3ms
# Speed: 0.0ms preprocess, 470.3ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 509 milliseconds
# FPS: 1.97
#
# 0: 640x640 1 FACE, 460.8ms
# Speed: 0.0ms preprocess, 460.8ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 502 milliseconds
# FPS: 1.99
#
# 0: 640x640 1 FACE, 493.2ms
# Speed: 0.0ms preprocess, 493.2ms inference, 10.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 537 milliseconds
# FPS: 1.86
#
# 0: 640x640 1 FACE, 441.0ms
# Speed: 0.0ms preprocess, 441.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 476 milliseconds
# FPS: 2.10
#
# 0: 640x640 (no detections), 418.4ms
# Speed: 0.0ms preprocess, 418.4ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 452 milliseconds
# FPS: 2.21
#
# 0: 640x640 1 FACE, 428.9ms
# Speed: 0.0ms preprocess, 428.9ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 461 milliseconds
# FPS: 2.17
#
# 0: 640x640 1 FACE, 486.6ms
# Speed: 0.0ms preprocess, 486.6ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 520 milliseconds
# FPS: 1.92
#
# 0: 640x640 1 FACE, 440.3ms
# Speed: 0.0ms preprocess, 440.3ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 481 milliseconds
# FPS: 2.08
#
# 0: 640x640 1 FACE, 442.3ms
# Speed: 0.0ms preprocess, 442.3ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 475 milliseconds
# FPS: 2.10
#
# 0: 640x640 1 FACE, 456.2ms
# Speed: 0.0ms preprocess, 456.2ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 491 milliseconds
# FPS: 2.04
#
# 0: 640x640 1 FACE, 443.8ms
# Speed: 0.0ms preprocess, 443.8ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 481 milliseconds
# FPS: 2.08
#
# 0: 640x640 1 FACE, 440.6ms
# Speed: 0.0ms preprocess, 440.6ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 479 milliseconds
# FPS: 2.09
#
# 0: 640x640 1 FACE, 417.1ms
# Speed: 0.0ms preprocess, 417.1ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# Time to process 1 frame: 452 milliseconds
# FPS: 2.21

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.9.0'
